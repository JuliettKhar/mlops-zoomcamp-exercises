# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5000'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/4', creation_time=1779754991690, experiment_id='4', last_update_time=1779754991690, lifecycle_stage='active', name='my-new-experiment-3', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/3', creation_time=1779754579706, experiment_id='3', last_update_time=1779754579706, lifecycle_stage='active', name='my-new-experiment-2', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/2', creation_time=1779685780232, experiment_id='2', last_update_time=1779685780232, lifecycle_stage='active', name='my-new-experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/0', creation_time=1779681958308, experiment_id='0', last_update_time=1779681958308, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2026/05/26 12:48:40 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/05/26 12:48:40 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/05/26 12:48:40 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# default artifacts URI: 'mlflow-artifacts:/5/906799431dba4a958469d36d0fbbbf3c/artifacts'
# 🏃 View run crawling-trout-763 at: http://127.0.0.1:5000/#/experiments/5/runs/906799431dba4a958469d36d0fbbbf3c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/5', creation_time=1779767320224, experiment_id='5', last_update_time=1779767320224, lifecycle_stage='active', name='my-experiment-1', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/4', creation_time=1779754991690, experiment_id='4', last_update_time=1779754991690, lifecycle_stage='active', name='my-new-experiment-3', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/3', creation_time=1779754579706, experiment_id='3', last_update_time=1779754579706, lifecycle_stage='active', name='my-new-experiment-2', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/2', creation_time=1779685780232, experiment_id='2', last_update_time=1779685780232, lifecycle_stage='active', name='my-new-experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/Users/julia/Desktop/Projects/mlops-zoomcamp-exercises/02-experiment-tracking/mlruns/0', creation_time=1779681958308, experiment_id='0', last_update_time=1779681958308, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5000")

# %%
client.search_registered_models()
# Out:
# [<RegisteredModel: aliases={}, creation_timestamp=1779756418083, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1779756418083, latest_versions=[], name='my-new-experiment', tags={}, workspace='default'>,
#  <RegisteredModel: aliases={}, creation_timestamp=1779751461101, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='the nyc taxi duration prediction', last_updated_timestamp=1779759051812, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1779751461158, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='nyc taxi predictor for trip duration', last_updated_timestamp=1779751677838, metrics=None, model_id=None, name='nyc-taxi-regressor', params=None, run_id='e20560ecbd23409cbb17d32899ae7435', run_link='', source='models:/m-aff75da99c4241f5ac20285c5fc14099', status='READY', status_message=None, tags={'model': 'xgboost'}, user_id='', version='1', workspace='default'>,
#   <ModelVersion: aliases=[], creation_timestamp=1779751547369, current_stage='Staging', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='The model version was transitioned to new stage on 2026-05-26', last_updated_timestamp=1779759852428, metrics=None, model_id=None, name='nyc-taxi-regressor', params=None, run_id='70839bde3fce412abe18aa869761f347', run_link='', source='models:/m-3cd6256d60494adba46a3cd5bc4f0bae', status='READY', status_message=None, tags={}, user_id='', version='2', workspace='default'>], name='nyc-taxi-regressor', tags={}, workspace='default'>,
#  <RegisteredModel: aliases={}, creation_timestamp=1779756589713, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1779756589713, latest_versions=[], name='xgboost', tags={}, workspace='default'>,
#  <RegisteredModel: aliases={}, creation_timestamp=1779756804690, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1779756804690, latest_versions=[], name='xgboost-taxi-regressor', tags={}, workspace='default'>,
#  <RegisteredModel: aliases={}, creation_timestamp=1779757013823, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1779757013823, latest_versions=[], name='xgboost-taxi-regressor-2', tags={}, workspace='default'>,
#  <RegisteredModel: aliases={}, creation_timestamp=1779757258407, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1779757258436, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1779757258436, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description=None, last_updated_timestamp=1779757258436, metrics=None, model_id=None, name='xgboost-taxi-regressor-2.1', params=None, run_id='e20560ecbd23409cbb17d32899ae7435', run_link='', source='models:/m-aff75da99c4241f5ac20285c5fc14099', status='READY', status_message=None, tags={}, user_id='', version='1', workspace='default'>], name='xgboost-taxi-regressor-2.1', tags={}, workspace='default'>]

# %%
for exp in client.search_experiments():
    print(exp.experiment_id, exp.name)
# Out:
# 5 my-experiment-1
# 4 my-new-experiment-3
# 3 my-new-experiment-2
# 2 my-new-experiment
# 0 Default

# %%
run_id = client.search_runs(experiment_ids='5')[0].info.run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# Successfully registered model 'iris-classifier'.
# 2026/05/26 12:52:25 WARNING mlflow.tracking._model_registry.fluent: Run with id 906799431dba4a958469d36d0fbbbf3c has no artifacts at artifact path 'models', registering model based on models:/m-86bfbc3b7f7347c6b6a6404377d04f06 instead
# 2026/05/26 12:52:25 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: iris-classifier, version 1
# Created version '1' of model 'iris-classifier'.
# <ModelVersion: aliases=[], creation_timestamp=1779767545385, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1779767545385, metrics=None, model_id=None, name='iris-classifier', params=None, run_id='906799431dba4a958469d36d0fbbbf3c', run_link='', source='models:/m-86bfbc3b7f7347c6b6a6404377d04f06', status='READY', status_message=None, tags={}, user_id='', version='1', workspace='default'>
